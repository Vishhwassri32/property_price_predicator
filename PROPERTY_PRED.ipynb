# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("/content/lucknow_hosuing_prices - Main File.csv")

# %%
data.head()
# Out:
#    bhk         type  area_sq_ft         location  price_lakh carpet_area  \
# 0    3  Independent        1100      Rajajipuram        33.0         720
# 1    3  Independent        1200   Sarojini Nagar        27.0         NaN
# 2    2  Independent        1250       Jankipuram        50.0        1000
# 3    3  Independent        1320       Omaxe City        42.0         900
# 4    3  Independent         900  Vrindavan Yojna        48.0
#
#         status  bathrooms
# 0  StatusReady          2
# 1  StatusUnder          2
# 2  StatusReady          2
# 3  StatusReady          3
# 4  StatusReady          2

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import BaggingRegressor
from sklearn.linear_model import LinearRegression

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score

# %%
df = pd.read_csv("/content/lucknow_hosuing_prices - Main File.csv")

# %%
df.dtypes
# Out:
# bhk              int64
# type            object
# area_sq_ft       int64
# location        object
# price_lakh     float64
# carpet_area     object
# status          object
# bathrooms        int64
# dtype: object

# %%
df.isna().sum()
# Out:
# bhk              0
# type             0
# area_sq_ft       0
# location         0
# price_lakh       0
# carpet_area    152
# status           0
# bathrooms        0
# dtype: int64

# %%
df = df.fillna(0)

# %%
df.head()
# Out:
#    bhk         type  area_sq_ft         location  price_lakh carpet_area  \
# 0    3  Independent        1100      Rajajipuram        33.0         720
# 1    3  Independent        1200   Sarojini Nagar        27.0           0
# 2    2  Independent        1250       Jankipuram        50.0        1000
# 3    3  Independent        1320       Omaxe City        42.0         900
# 4    3  Independent         900  Vrindavan Yojna        48.0
#
#         status  bathrooms
# 0  StatusReady          2
# 1  StatusUnder          2
# 2  StatusReady          2
# 3  StatusReady          3
# 4  StatusReady          2

# %%
location_count = df['location'].value_counts()
location_count = location_count.reset_index()
at_least_5 = (len(df)*5)/100
req_location = location_count[location_count['count']>=at_least_5]
req_location
# Out:
#         location  count
# 0  Faizabad Road     52
# 1     Jankipuram     49
# 2     Kursi Road     32
# 3   Sitapur Road     24

# %%
df_req = df[df['location'].isin(req_location['location'])]

# %%
df_req.head()
# Out:
#     bhk         type  area_sq_ft    location  price_lakh carpet_area  \
# 2     2  Independent        1250  Jankipuram        50.0        1000
# 10    2  Independent         850  Jankipuram        27.0         600
# 16    2  Independent        1500  Jankipuram        42.0        1250
# 26    2  Independent        1100  Jankipuram        44.0         700
# 29    2  Independent        1100  Jankipuram        46.0        1000
#
#          status  bathrooms
# 2   StatusReady          2
# 10  StatusUnder          1
# 16  StatusReady          2
# 26  StatusReady          2
# 29  StatusReady          2

# %%
df_req  = pd.concat([df_req,df],axis='columns')

# %%
df_req['carpet_area'].replace(' ',0,inplace=True)
# Out:
# <ipython-input-55-1200209dbd6b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_req['carpet_area'].replace(' ',0,inplace=True)

# %%
to_be_scaled = df_req[['area_sq_ft','price_lakh','carpet_area']]

# %%
scale = StandardScaler()

# %%
df_req.drop(columns=['type','location','status'],inplace=True)

# %%
df_req
# Out:
#      bhk  area_sq_ft  price_lakh carpet_area  bathrooms  bhk  area_sq_ft  \
# 2    2.0      1250.0        50.0        1000        2.0    2        1250
# 10   2.0       850.0        27.0         600        1.0    2         850
# 16   2.0      1500.0        42.0        1250        2.0    2        1500
# 26   2.0      1100.0        44.0         700        2.0    2        1100
# 29   2.0      1100.0        46.0        1000        2.0    2        1100
# ..   ...         ...         ...         ...        ...  ...         ...
# 460  NaN         NaN         NaN         NaN        NaN    2         800
# 463  NaN         NaN         NaN         NaN        NaN    2        1000
# 464  NaN         NaN         NaN         NaN        NaN    3        1500
# 466  NaN         NaN         NaN         NaN        NaN    2        1250
# 472  NaN         NaN         NaN         NaN        NaN    2         900
#
#      price_lakh carpet_area  bathrooms
# 2          50.0        1000          2
# 10         27.0         600          1
# 16         42.0        1250          2
# 26         44.0         700          2
# 29         46.0        1000          2
# ..          ...         ...        ...
# 460        30.4         799          2
# 463        49.5           0          2
# 464        49.9        1000          3
# 466        45.0           0          2
# 472        22.5           0          2
#
# [474 rows x 10 columns]

# %%
X = df_req.drop(columns='price_lakh')
y = df_req['price_lakh']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

# %%
model = LinearRegression()

# %%
len(X_train)
# Out:
# 379

# %%
bag_model = BaggingRegressor(estimator=LinearRegression(),
                        n_estimators=10,max_samples=1.0,oob_score=False)
